# %% [markdown]
# ## Handling Exceptions

# %%
try:
  ...
  ...
except IndexError:
  ...
except (NameError, KeyError):
  ...
except:
  ...
else:
  ...
# Out:
#   File "<ipython-input-1-c2831a25e942>", line 8
#     except:
#            ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ## Using Exceptions 'positively'

# %% [markdown]
# ### Traditional approach

# %%
if b in scores.keys():
  scores[b].append(s)
else:
  scores[b] = [s]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2696f84dc87c> in <module>
# ----> 1 if b in scores.keys():
#       2   scores[b].append(s)
#       3 else:
#       4   scores[b] = [s]
#
# NameError: name 'b' is not defined

# %% [markdown]
# ### Using exceptions

# %%
try:
  scores[b].append(s)
except KeyError:
  scores[b] = [s]
